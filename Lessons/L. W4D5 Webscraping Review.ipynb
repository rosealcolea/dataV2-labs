# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.worldometers.info/coronavirus/'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %%
# tags = ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'p']
# soup.find_all(tags)
# text = [element.text for element in ]
# text
# Out:
# bs4.element.Tag

# %%
cdict = {'class':'resultsarchive-table'}
iddict = {'id':'main_table_countries_today'}

table = soup.find_all('table',iddict)[0]
table
# Out:
# <table class="table table-bordered table-hover main_table_countries" id="main_table_countries_today" style="width:100%;margin-top: 0px !important;display:none;">
# <thead>
# <tr>
# <th width="1%">#</th>
# <th width="100">Country,<br/>Other</th>
# <th width="20">Total<br/>Cases</th>
# <th width="30">New<br/>Cases</th>
# <th width="30">Total<br/>Deaths</th>
# <th width="30">New<br/>Deaths</th>
# <th width="30">Total<br/>Recovered</th>
# <th width="30">New<br/>Recovered</th>
# <th width="30">Active<br/>Cases</th>
# <th width="30">Serious,<br/>Critical</th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# <th width="30">Deaths/<br/>1M pop</th>
# <th width="30">Total<br/>Tests</th>
# <th width="30">Tests/<br/>
# <nobr>1M pop</nobr>
# </th>
# <th width="30">Population</th>
# <th style="display:none" width="30">Continent</th>
# <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
# </tr>
# </thead>
# <tbody>
# ...

# %%
tags = ['thead','tbody']
tableparts = table.find_all(tags)
thead = tableparts[0]
tbody = tableparts[1]
tbody
# Out:
# <tbody>
# <tr class="total_row_world row_continent" data-continent="North America" style="display: none">
# <td></td>
# <td style="text-align:left;">
# <nobr>North America</nobr>
# </td>
# <td>1,985,494</td>
# <td>+4,307</td>
# <td>120,654</td>
# <td>+480</td>
# <td>624,697</td>
# <td>+2,396</td>
# <td>1,240,143</td>
# <td>19,456</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="North America" style="display:none;">North America</td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="total_row_world row_continent" data-continent="South America" style="display: none">
# <td></td>
# <td style="text-align:left;">
# <nobr>South America</nobr>
# </td>
# <td>758,107</td>
# <td>+619</td>
# <td>36,746</td>
# <td>+13</td>
# <td>320,826</td>
# <td>+49</td>
# <td>400,535</td>
# <td>11,077</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="South America" style="display:none;">South America</td>
# <td>
# </td>
# ...

# %%
tags = ['tr']
rows = tbody.find_all('tr')
l_o_l = [[x.text for x in row.find_all('td')] for row in rows]
l_o_l
# Out:
# [['',
#   '\nNorth America\n',
#   '1,985,494',
#   '+4,307',
#   '120,654',
#   '+480',
#   '624,697',
#   '+2,396',
#   '1,240,143',
#   '19,456',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'North America',
#   '\n',
#   '',
#   ''],
#  ['',
#   '\nSouth America\n',
#   '758,107',
#   '+619',
#   '36,746',
#   '+13',
#   '320,826',
#   '+49',
#   '400,535',
#   '11,077',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'South America',
#   '\n',
#   '',
#   ''],
#  ['',
#   '\nEurope\n',
#   '1,982,048',
#   '+12,149',
#   '172,017',
#   '+449',
#   '960,087',
#   '+11,591',
#   '849,944',
#   '9,354',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Europe',
#   '\n',
#   '',
#   ''],
#  ['',
#   '\nAsia\n',
#   '1,069,380',
#   '+18,114',
#   '29,399',
#   '+279',
#   '635,449',
#   '+13,705',
#   '404,532',
#   '13,704',
#   '',
#   '',
#   '',
#   '',
#   '',
#   'Asia',
#   '\n',
#   '',
#   ''],
#  ['',
#   '\nAfrica\n',
#   '132,668',
#   '+1,081',
#   '3,820',
#   '+6',
# ...

# %%
import pandas as pd
tbodyDF = pd.DataFrame(l_o_l)

# %%
tbodyDF.head(60)
# Out:
#      0                   1          2        3         4       5          6  \
# 0        \nNorth America\n  1,985,494   +4,307   120,654    +480    624,697
# 1        \nSouth America\n    758,107     +619    36,746     +13    320,826
# 2               \nEurope\n  1,982,048  +12,149   172,017    +449    960,087
# 3                 \nAsia\n  1,069,380  +18,114    29,399    +279    635,449
# 4               \nAfrica\n    132,668   +1,081     3,820      +6     55,300
# 5              \nOceania\n      8,782      +23       125              8,164
# 6                     \n\n        721                 15                651
# 7                    World  5,937,200  +36,293   362,776  +1,227  2,605,174
# 8    1                 USA  1,768,868     +407  103,345      +15    498,762
# 9    2              Brazil    438,812            26,764             193,181
# 10   3              Russia    387,623   +8,572    4,374     +232    159,257
# ...

# %%
rows = table.find_all('tr')
# rows = [row.text.strip().split('\n') for row in rows]
# rows
rows = [row.text.strip().replace('\xa0', '').split('\n') for row in rows]
rows
rows = [[x for x in row if x != ''] for row in rows]
rows
# Out:
# [['#',
#   'Country,Other',
#   'TotalCases',
#   'NewCases',
#   'TotalDeaths',
#   'NewDeaths',
#   'TotalRecovered',
#   'NewRecovered',
#   'ActiveCases',
#   'Serious,Critical',
#   'TotCases/1M pop',
#   'Deaths/1M pop',
#   'TotalTests',
#   'Tests/',
#   '1M pop',
#   'Population',
#   'Continent',
#   '1 Caseevery X ppl1 Deathevery X ppl1 Testevery X ppl'],
#  ['North America',
#   '1,985,494',
#   '+4,307',
#   '120,654',
#   '+480',
#   '624,697',
#   '+2,396',
#   '1,240,143',
#   '19,456',
#   'North America'],
#  ['South America',
#   '758,107',
#   '+619',
#   '36,746',
#   '+13',
#   '320,826',
#   '+49',
#   '400,535',
#   '11,077',
#   'South America'],
#  ['Europe',
#   '1,982,048',
#   '+12,149',
#   '172,017',
#   '+449',
#   '960,087',
#   '+11,591',
#   '849,944',
#   '9,354',
#   'Europe'],
#  ['Asia',
#   '1,069,380',
#   '+18,114',
#   '29,399',
#   '+279',
#   '635,449',
#   '+13,705',
#   '404,532',
#   '13,704',
#   'Asia'],
#  ['Africa',
#   '132,668',
# ...

# %%
colnames = rows[0]
data = rows[1:]

# %%
import pandas as pd
df = pd.DataFrame(data, columns=colnames)
df
