# %%
import pandas as pd

# %%
# Import comma-separated variable file
data = pd.read_csv('vehicles/vehicle.csv')
# same as: data = pd.read_csv('vehicles/vehicle.csv', sep=',')

# Import tab-delimited file
data2 = pd.read_csv('vehicles/vehicles_tab.txt', sep='\t')

# Import pipe-delimited file
data3 = pd.read_csv('vehicles/vehicles_pipe.txt', sep='|')
#Make|Model|Year|Engine Displacement|Cylinders|Transmission|Drivetrain|Vehicle Class|Fuel Type|Fuel Barrels/Year|City MPG|Highway MPG|Combined MPG|CO2 Emission Grams/Mile|Fuel Cost/Year

# %%
data3
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
# Export comma-separated variable file
data.to_csv('vehicles/vehicles_export.csv', index=False)

# Export tab-delimited file
data.to_csv('vehicles/vehicles_tab_export.txt', sep='\t', index=False)

# Export pipe-delimited file
data.to_csv('vehicles/vehicles_pipe_export.txt', sep='|', index=False)

# %%
data4 = pd.read_excel('vehicles/vehicles.xlsx')

data4

data4.to_excel('vehicles/vehicles_export.xlsx', index=False)

# %%
data5 = pd.read_json('vehicles/vehicles.json', orient='records')

data5.to_json('vehicles/vehicles_export.json', orient='index')
data5
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
import pymysql
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:xxxxxxxx@localhost:3306/publications')

# %%
data6 = pd.read_sql_query('SELECT * FROM publications.employee', engine)

# %%
data6

# %%
data6.to_sql('employee2', engine, if_exists='replace', index=False)

# %%
# now you can also import a csv file directly from a url - if you have access obviously
data7=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst',header=None)

# %%
data7
