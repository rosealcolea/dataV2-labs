# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import sys
# !{sys.executable} -m pip install stackapi
# Out:
# ...
#   Using cached StackAPI-0.1.12.tar.gz (5.5 kB)
# ...
#   Created wheel for stackapi: filename=StackAPI-0.1.12-py3-none-any.whl size=5673 sha256=fb623e50dc24155bd4014c99f6bf515cc276fcea13afa140e2a844d2294dacf0
#   Stored in directory: c:\users\irenl\appdata\local\pip\cache\wheels\69\20\49\92e2edda746b536f1f9f81536cbe5463fffdfa20465a47ee3d
# Successfully built stackapi
# ...

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
import re
import numpy as np
from stackapi import StackAPI

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1585699200, todate=1588291200)
answers = SITE.fetch('answers', fromdate=1585699200, todate=1588291200)

# %%
questions_df = pd.DataFrame(questions)
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['web-services', 'xamarin', 'mvvm', 'fonts', 'icons'],
#    'owner': {'reputation': 9,
#     'user_id': 12190286,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/990fa0d081fa59d2d9dbe118430a82e9?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Aaron B',
#     'link': 'https://stackoverflow.com/users/12190286/aaron-b'},
#    'is_answered': True,
#    'view_count': 46,
#    'accepted_answer_id': 61939986,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1590081101,
#    'creation_date': 1588197863,
#    'question_id': 61512534,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/61512534/display-xamarin-font-icons-from-stored-data',
#    'title': 'Display Xamarin Font Icons From Stored Data'},
# ...

# %%
answers_df = pd.DataFrame(answers)
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 178,
#     'user_id': 1124303,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/kheL9.jpg?s=128&g=1',
#     'display_name': 'Kartik Shah',
#     'link': 'https://stackoverflow.com/users/1124303/kartik-shah'},
#    'is_accepted': False,
#    'score': 1,
#    'last_activity_date': 1590078581,
#    'last_edit_date': 1590078581,
#    'creation_date': 1586625358,
#    'answer_id': 61160758,
#    'question_id': 37765356,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 1,
#     'user_id': 2695864,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/09c26fe123ae7657ad7efaca15d8c0f0?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Javier',
#     'link': 'https://stackoverflow.com/users/2695864/javier'},
#    'is_accepted': False,
#    'score': 0,
# ...

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %%
nested_columns = ['items']

questions_flat = flatten(questions, nested_columns)
questions_flat.head()

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here
filtered = questions_df[(questions_df['score']>=5)] #& 
                #(questions_df['Cylinders']==['python'])]

filtered.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'score'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-ebe17956a225> in <module>
#       1 # your code here
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
ids = pd.DataFrame[[answers.str.contains('6784|6473')]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-26b49c7f7337> in <module>
#       1 # your code here
# ----> 2 AMS_postcodes = pd.DataFrame[[answers.str.contains('6784')]]
#
# AttributeError: 'dict' object has no attribute 'str'

# %%
pattern = ('6784|6473')
ids = re.findall(pattern, pd.DataFrame[questions]).index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-b57d99331ac3> in <module>
#       1 pattern = ('6784|6473')
# ----> 2 ids = re.findall(pattern, pd.DataFrame[questions]).index
#
# TypeError: 'type' object is not subscriptable

# %%
ids = []
for i in answers:
    for ii in i:
        for iii in ii:
            for iiii in iii:
                ids.append(answers.get('answer_id'))
ids
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
